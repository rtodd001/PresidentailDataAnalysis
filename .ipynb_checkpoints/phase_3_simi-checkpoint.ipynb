# %% [markdown]
# ## Did the impeachment skew the polls significantly?
# ## Was it predicatable?

# %% [markdown]
# Let's review the timeline of everything before we start
#
# - September-November : Inquiry
# - December 18, 2020 : Impeached by US HoR
# - January 16, 2020 : Passed the Senate
# - February 5, 2020 : Acquitted

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## What was Donald Trump's approval rating during his impeachment trial?

# %%
approval_df = pd.read_csv("president_approval_polls.csv")
approval_df.head()
# Out:
#    question_id  poll_id   cycle  state    politician  pollster_id  \
# 0       119194    64608  2020.0    NaN  Donald Trump          399
# 1       119031    64571  2020.0    NaN  Donald Trump         1189
# 2       119032    64571  2020.0    NaN  Donald Trump         1189
# 3       119075    64583  2020.0    NaN  Donald Trump          399
# 4       119267    64591  2020.0    NaN  Donald Trump          590
#
#                                        pollster sponsor_ids sponsors  \
# 0      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 1                               Morning Consult         NaN      NaN
# 2                               Morning Consult         NaN      NaN
# 3      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 4  Fox News/Beacon Research/Shaw & Co. Research         NaN      NaN
#
#                                display_name  ...  start_date end_date  \
# 0  Rasmussen Reports/Pulse Opinion Research  ...     2/25/20  2/27/20
# 1                           Morning Consult  ...     2/24/20  2/26/20
# 2                           Morning Consult  ...     2/24/20  2/26/20
# 3  Rasmussen Reports/Pulse Opinion Research  ...     2/24/20  2/26/20
# 4                                  Fox News  ...     2/23/20  2/26/20
#
#   sponsor_candidate  tracking     created_at notes  \
# 0               NaN      True  2/28/20 09:27   NaN
# 1               NaN       NaN  2/26/20 15:33   NaN
# 2               NaN       NaN  2/26/20 15:33   NaN
# 3               NaN      True  2/27/20 09:26   NaN
# 4               NaN       NaN  2/28/20 18:00   NaN
#
#                                                  url source   yes    no
# 0  http://www.rasmussenreports.com/public_content...    538  47.0  52.0
# 1  https://morningconsult.com/wp-content/uploads/...    538  42.0  53.0
# 2  https://morningconsult.com/wp-content/uploads/...    538  43.0  55.0
# 3  http://www.rasmussenreports.com/public_content...    538  52.0  47.0
# 4  https://www.scribd.com/document/449414637/Fox-...    538  47.0  52.0
#
# [5 rows x 27 columns]

# %%
approval_df.dtypes
# Out:
# question_id               int64
# poll_id                   int64
# cycle                   float64
# state                   float64
# politician               object
# pollster_id               int64
# pollster                 object
# sponsor_ids              object
# sponsors                 object
# display_name             object
# pollster_rating_id      float64
# pollster_rating_name     object
# fte_grade                object
# sample_size               int64
# population               object
# population_full          object
# methodology              object
# start_date               object
# end_date                 object
# sponsor_candidate       float64
# tracking                 object
# created_at               object
# notes                    object
# url                      object
# source                   object
# yes                     float64
# no                      float64
# dtype: object

# %% [markdown]
# ### Impeached by the US HoR: Dec 18, 2019
#
# Timeline of data is from Dec 18, 2019 - Jan 14, 2020

# %%
house = approval_df.loc[224:330].copy()
house.head()
# Out:
#      question_id  poll_id   cycle  state    politician  pollster_id pollster  \
# 224       115710    63278  2020.0    NaN  Donald Trump          568   YouGov
# 225       115711    63278  2020.0    NaN  Donald Trump          568   YouGov
# 226       115828    63286  2020.0    NaN  Donald Trump         1447   Civiqs
# 227       115638    63261  2020.0    NaN  Donald Trump          568   YouGov
# 228       115639    63261  2020.0    NaN  Donald Trump          568   YouGov
#
#     sponsor_ids   sponsors display_name  ...  start_date end_date  \
# 224         352  Economist       YouGov  ...     1/11/20  1/14/20
# 225         352  Economist       YouGov  ...     1/11/20  1/14/20
# 226         185  Daily Kos       Civiqs  ...     1/11/20  1/14/20
# 227         NaN        NaN       YouGov  ...     1/11/20  1/13/20
# 228         NaN        NaN       YouGov  ...     1/11/20  1/13/20
#
#     sponsor_candidate  tracking     created_at notes  \
# 224               NaN       NaN  1/15/20 09:19   NaN
# 225               NaN       NaN  1/15/20 09:19   NaN
# 226               NaN       NaN  1/16/20 08:45   NaN
# 227               NaN       NaN  1/13/20 14:51   NaN
# 228               NaN       NaN  1/13/20 14:51   NaN
#
#                                                    url source   yes    no
# 224  https://d25d2506sfb94s.cloudfront.net/cumulus_...    538  44.0  48.0
# 225  https://d25d2506sfb94s.cloudfront.net/cumulus_...    538  46.0  50.0
# 226  https://civiqs.com/documents/Civiqs_DailyKos_m...    538  45.0  53.0
# 227  https://d25d2506sfb94s.cloudfront.net/cumulus_...    538  39.0  52.0
# 228  https://d25d2506sfb94s.cloudfront.net/cumulus_...    538  42.0  55.0
#
# [5 rows x 27 columns]

# %%
house_df = house.set_index('poll_id')
A = np.arange(len(house_df))
A = np.flip(A,0)
house_df['count'] = A
house_df.reset_index(inplace = True)
house_df
# Out:
#      poll_id  question_id   cycle  state    politician  pollster_id  \
# 0      63278       115710  2020.0    NaN  Donald Trump          568
# 1      63278       115711  2020.0    NaN  Donald Trump          568
# 2      63286       115828  2020.0    NaN  Donald Trump         1447
# 3      63261       115638  2020.0    NaN  Donald Trump          568
# 4      63261       115639  2020.0    NaN  Donald Trump          568
# ..       ...          ...     ...    ...           ...          ...
# 102    63154       115079  2019.0    NaN  Donald Trump          399
# 103    63177       115132  2020.0    NaN  Donald Trump          568
# 104    63177       115133  2020.0    NaN  Donald Trump          568
# 105    63183       115143  2020.0    NaN  Donald Trump          294
# 106    63145       114969  2020.0    NaN  Donald Trump          744
#
#                                      pollster sponsor_ids   sponsors  \
# 0                                      YouGov         352  Economist
# 1                                      YouGov         352  Economist
# 2                                      Civiqs         185  Daily Kos
# 3                                      YouGov         NaN        NaN
# 4                                      YouGov         NaN        NaN
# ..                                        ...         ...        ...
# 102  Rasmussen Reports/Pulse Opinion Research         NaN        NaN
# 103                                    YouGov         NaN        NaN
# 104                                    YouGov         NaN        NaN
# 105                   McLaughlin & Associates         NaN        NaN
# 106                                     Ipsos          71    Reuters
#
#                                  display_name  ...  end_date  \
# 0                                      YouGov  ...   1/14/20
# 1                                      YouGov  ...   1/14/20
# 2                                      Civiqs  ...   1/14/20
# 3                                      YouGov  ...   1/13/20
# 4                                      YouGov  ...   1/13/20
# ..                                        ...  ...       ...
# 102  Rasmussen Reports/Pulse Opinion Research  ...  12/18/19
# 103                                    YouGov  ...  12/18/19
# 104                                    YouGov  ...  12/18/19
# 105                   McLaughlin & Associates  ...  12/18/19
# 106                                     Ipsos  ...  12/17/19
#
#     sponsor_candidate tracking      created_at notes  \
# 0                 NaN      NaN   1/15/20 09:19   NaN
# 1                 NaN      NaN   1/15/20 09:19   NaN
# 2                 NaN      NaN   1/16/20 08:45   NaN
# 3                 NaN      NaN   1/13/20 14:51   NaN
# 4                 NaN      NaN   1/13/20 14:51   NaN
# ..                ...      ...             ...   ...
# 102               NaN     True  12/19/19 09:31   NaN
# 103               NaN      NaN  12/23/19 13:11   NaN
# 104               NaN      NaN  12/23/19 13:11   NaN
# 105               NaN      NaN  12/23/19 14:41   NaN
# 106               NaN      NaN  12/18/19 08:48   NaN
#
#                                                    url     source   yes    no  \
# 0    https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  44.0  48.0
# 1    https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  46.0  50.0
# 2    https://civiqs.com/documents/Civiqs_DailyKos_m...        538  45.0  53.0
# 3    https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  39.0  52.0
# 4    https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  42.0  55.0
# ..                                                 ...        ...   ...   ...
# 102  http://www.rasmussenreports.com/public_content...  Rasmussen  49.0  49.0
# 103  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  42.0  51.0
# 104  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  44.0  54.0
# 105  https://mclaughlinonline.com/pols/wp-content/u...        538  46.0  53.0
# 106  https://www.ipsos.com/sites/default/files/ct/n...        538  41.0  53.0
#
#      count
# 0      106
# 1      105
# 2      104
# 3      103
# 4      102
# ..     ...
# 102      4
# 103      3
# 104      2
# 105      1
# 106      0
#
# [107 rows x 28 columns]

# %%
house_df.plot(kind='line', x='count', y='yes')

# %%
house_df_train = house_df.loc[80:].copy()
house_df_test = house_df.loc[:81].copy()

X_train = house_df_train[["count"]]
X_test = house_df_test[["count"]]
y_train = house_df_train["yes"]

model = LinearRegression()
model.fit(X=X_train, y=y_train)
model.predict(X=X_test)

X_new = pd.DataFrame()
# create a sequence of 200 evenly spaced numbers from 0 to 50
X_new["count"] = np.linspace(0, 26, num=5)

# create a Series out of the predicted values
# (trailing underscore indicates fitted values)
y_new_ = pd.Series(
    model.predict(X_new), # y values in Series.plot.line()
    index=X_new["count"]    # x values in Series.plot.line()
)

# plot the data, then the model
house_df_train.plot.line(x="count", y="yes")
y_new_.plot.line(color='orange')

# %% [markdown]
# ### Passed the Senate: Jan 16, 2020
#
# Timeline of data is from Dec 18, 2019 - Feb 1, 2020

# %%
senate = approval_df.loc[125:330].copy()
senate.head()
# Out:
#      question_id  poll_id   cycle  state    politician  pollster_id  \
# 125       116772    63498  2020.0    NaN  Donald Trump          568
# 126       116773    63498  2020.0    NaN  Donald Trump          568
# 127       116770    63497  2020.0    NaN  Donald Trump          568
# 128       116771    63497  2020.0    NaN  Donald Trump          568
# 129       116441    63418  2020.0    NaN  Donald Trump         1189
#
#             pollster sponsor_ids  sponsors     display_name  ...  start_date  \
# 125           YouGov         NaN       NaN           YouGov  ...     1/30/20
# 126           YouGov         NaN       NaN           YouGov  ...     1/30/20
# 127           YouGov         NaN       NaN           YouGov  ...     1/29/20
# 128           YouGov         NaN       NaN           YouGov  ...     1/29/20
# 129  Morning Consult         538  Politico  Morning Consult  ...     1/29/20
#
#     end_date sponsor_candidate  tracking     created_at notes  \
# 125   2/1/20               NaN       NaN  2/10/20 15:20   NaN
# 126   2/1/20               NaN       NaN  2/10/20 15:20   NaN
# 127  1/31/20               NaN       NaN  2/10/20 15:20   NaN
# 128  1/31/20               NaN       NaN  2/10/20 15:20   NaN
# 129  1/30/20               NaN       NaN   2/1/20 08:13   NaN
#
#                                                    url source   yes    no
# 125  https://d25d2506sfb94s.cloudfront.net/cumulus_...    538  40.0  53.0
# 126  https://d25d2506sfb94s.cloudfront.net/cumulus_...    538  45.0  54.0
# 127  https://d25d2506sfb94s.cloudfront.net/cumulus_...    538  41.0  52.0
# 128  https://d25d2506sfb94s.cloudfront.net/cumulus_...    538  44.0  54.0
# 129  https://morningconsult.com/wp-content/uploads/...    538  43.0  54.0
#
# [5 rows x 27 columns]

# %%
senate_df = senate.set_index('poll_id')
B = np.arange(len(senate_df))
B = np.flip(B,0)
senate_df['count'] = B
senate_df.reset_index(inplace = True)
senate_df
# Out:
#      poll_id  question_id   cycle  state    politician  pollster_id  \
# 0      63498       116772  2020.0    NaN  Donald Trump          568
# 1      63498       116773  2020.0    NaN  Donald Trump          568
# 2      63497       116770  2020.0    NaN  Donald Trump          568
# 3      63497       116771  2020.0    NaN  Donald Trump          568
# 4      63418       116441  2020.0    NaN  Donald Trump         1189
# ..       ...          ...     ...    ...           ...          ...
# 201    63154       115079  2019.0    NaN  Donald Trump          399
# 202    63177       115132  2020.0    NaN  Donald Trump          568
# 203    63177       115133  2020.0    NaN  Donald Trump          568
# 204    63183       115143  2020.0    NaN  Donald Trump          294
# 205    63145       114969  2020.0    NaN  Donald Trump          744
#
#                                      pollster sponsor_ids  sponsors  \
# 0                                      YouGov         NaN       NaN
# 1                                      YouGov         NaN       NaN
# 2                                      YouGov         NaN       NaN
# 3                                      YouGov         NaN       NaN
# 4                             Morning Consult         538  Politico
# ..                                        ...         ...       ...
# 201  Rasmussen Reports/Pulse Opinion Research         NaN       NaN
# 202                                    YouGov         NaN       NaN
# 203                                    YouGov         NaN       NaN
# 204                   McLaughlin & Associates         NaN       NaN
# 205                                     Ipsos          71   Reuters
#
#                                  display_name  ...  end_date  \
# 0                                      YouGov  ...    2/1/20
# 1                                      YouGov  ...    2/1/20
# 2                                      YouGov  ...   1/31/20
# 3                                      YouGov  ...   1/31/20
# 4                             Morning Consult  ...   1/30/20
# ..                                        ...  ...       ...
# 201  Rasmussen Reports/Pulse Opinion Research  ...  12/18/19
# 202                                    YouGov  ...  12/18/19
# 203                                    YouGov  ...  12/18/19
# 204                   McLaughlin & Associates  ...  12/18/19
# 205                                     Ipsos  ...  12/17/19
#
#     sponsor_candidate tracking      created_at notes  \
# 0                 NaN      NaN   2/10/20 15:20   NaN
# 1                 NaN      NaN   2/10/20 15:20   NaN
# 2                 NaN      NaN   2/10/20 15:20   NaN
# 3                 NaN      NaN   2/10/20 15:20   NaN
# 4                 NaN      NaN    2/1/20 08:13   NaN
# ..                ...      ...             ...   ...
# 201               NaN     True  12/19/19 09:31   NaN
# 202               NaN      NaN  12/23/19 13:11   NaN
# 203               NaN      NaN  12/23/19 13:11   NaN
# 204               NaN      NaN  12/23/19 14:41   NaN
# 205               NaN      NaN  12/18/19 08:48   NaN
#
#                                                    url     source   yes    no  \
# 0    https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  40.0  53.0
# 1    https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  45.0  54.0
# 2    https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  41.0  52.0
# 3    https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  44.0  54.0
# 4    https://morningconsult.com/wp-content/uploads/...        538  43.0  54.0
# ..                                                 ...        ...   ...   ...
# 201  http://www.rasmussenreports.com/public_content...  Rasmussen  49.0  49.0
# 202  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  42.0  51.0
# 203  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  44.0  54.0
# 204  https://mclaughlinonline.com/pols/wp-content/u...        538  46.0  53.0
# 205  https://www.ipsos.com/sites/default/files/ct/n...        538  41.0  53.0
#
#      count
# 0      205
# 1      204
# 2      203
# 3      202
# 4      201
# ..     ...
# 201      4
# 202      3
# 203      2
# 204      1
# 205      0
#
# [206 rows x 28 columns]

# %%
senate_df.plot(kind='line', x='count', y='yes')

# %%
senate_df_train = senate_df.loc[154:].copy()
senate_df_test = senate_df.loc[:155].copy()

senate_X_train = senate_df_train[["count"]]
senate_X_test = senate_df_test[["count"]]
senate_y_train = senate_df_train["yes"]

senate_model = LinearRegression()
senate_model.fit(X=senate_X_train, y=senate_y_train)
senate_model.predict(X=senate_X_test)

senate_X_new = pd.DataFrame()
# create a sequence of 200 evenly spaced numbers from 0 to 50
senate_X_new["count"] = np.linspace(0, 51, num=5)

# create a Series out of the predicted values
# (trailing underscore indicates fitted values)
senate_y_new_ = pd.Series(
    senate_model.predict(senate_X_new), # y values in Series.plot.line()
    index=senate_X_new["count"]    # x values in Series.plot.line()
)

# plot the data, then the model
senate_df_train.plot.line(x="count", y="yes")
senate_y_new_.plot.line(color='orange')

# %% [markdown]
# ### Acquitted: Feb 5, 2020
#
# Timeline of data is from Dec 18, 2019 - Feb 27, 2020

# %%
acquitted = approval_df.loc[0:330].copy()
acquitted.head()
# Out:
#    question_id  poll_id   cycle  state    politician  pollster_id  \
# 0       119194    64608  2020.0    NaN  Donald Trump          399
# 1       119031    64571  2020.0    NaN  Donald Trump         1189
# 2       119032    64571  2020.0    NaN  Donald Trump         1189
# 3       119075    64583  2020.0    NaN  Donald Trump          399
# 4       119267    64591  2020.0    NaN  Donald Trump          590
#
#                                        pollster sponsor_ids sponsors  \
# 0      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 1                               Morning Consult         NaN      NaN
# 2                               Morning Consult         NaN      NaN
# 3      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 4  Fox News/Beacon Research/Shaw & Co. Research         NaN      NaN
#
#                                display_name  ...  start_date end_date  \
# 0  Rasmussen Reports/Pulse Opinion Research  ...     2/25/20  2/27/20
# 1                           Morning Consult  ...     2/24/20  2/26/20
# 2                           Morning Consult  ...     2/24/20  2/26/20
# 3  Rasmussen Reports/Pulse Opinion Research  ...     2/24/20  2/26/20
# 4                                  Fox News  ...     2/23/20  2/26/20
#
#   sponsor_candidate  tracking     created_at notes  \
# 0               NaN      True  2/28/20 09:27   NaN
# 1               NaN       NaN  2/26/20 15:33   NaN
# 2               NaN       NaN  2/26/20 15:33   NaN
# 3               NaN      True  2/27/20 09:26   NaN
# 4               NaN       NaN  2/28/20 18:00   NaN
#
#                                                  url source   yes    no
# 0  http://www.rasmussenreports.com/public_content...    538  47.0  52.0
# 1  https://morningconsult.com/wp-content/uploads/...    538  42.0  53.0
# 2  https://morningconsult.com/wp-content/uploads/...    538  43.0  55.0
# 3  http://www.rasmussenreports.com/public_content...    538  52.0  47.0
# 4  https://www.scribd.com/document/449414637/Fox-...    538  47.0  52.0
#
# [5 rows x 27 columns]

# %%
acq_df = acquitted.set_index('poll_id')
C = np.arange(len(acq_df))
C = np.flip(C,0)
acq_df['count'] = C
acq_df.reset_index(inplace = True)
acq_df
# Out:
#      poll_id  question_id   cycle  state    politician  pollster_id  \
# 0      64608       119194  2020.0    NaN  Donald Trump          399
# 1      64571       119031  2020.0    NaN  Donald Trump         1189
# 2      64571       119032  2020.0    NaN  Donald Trump         1189
# 3      64583       119075  2020.0    NaN  Donald Trump          399
# 4      64591       119267  2020.0    NaN  Donald Trump          590
# ..       ...          ...     ...    ...           ...          ...
# 326    63154       115079  2019.0    NaN  Donald Trump          399
# 327    63177       115132  2020.0    NaN  Donald Trump          568
# 328    63177       115133  2020.0    NaN  Donald Trump          568
# 329    63183       115143  2020.0    NaN  Donald Trump          294
# 330    63145       114969  2020.0    NaN  Donald Trump          744
#
#                                          pollster sponsor_ids sponsors  \
# 0        Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 1                                 Morning Consult         NaN      NaN
# 2                                 Morning Consult         NaN      NaN
# 3        Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 4    Fox News/Beacon Research/Shaw & Co. Research         NaN      NaN
# ..                                            ...         ...      ...
# 326      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 327                                        YouGov         NaN      NaN
# 328                                        YouGov         NaN      NaN
# 329                       McLaughlin & Associates         NaN      NaN
# 330                                         Ipsos          71  Reuters
#
#                                  display_name  ...  end_date  \
# 0    Rasmussen Reports/Pulse Opinion Research  ...   2/27/20
# 1                             Morning Consult  ...   2/26/20
# 2                             Morning Consult  ...   2/26/20
# 3    Rasmussen Reports/Pulse Opinion Research  ...   2/26/20
# 4                                    Fox News  ...   2/26/20
# ..                                        ...  ...       ...
# 326  Rasmussen Reports/Pulse Opinion Research  ...  12/18/19
# 327                                    YouGov  ...  12/18/19
# 328                                    YouGov  ...  12/18/19
# 329                   McLaughlin & Associates  ...  12/18/19
# 330                                     Ipsos  ...  12/17/19
#
#     sponsor_candidate tracking      created_at notes  \
# 0                 NaN     True   2/28/20 09:27   NaN
# 1                 NaN      NaN   2/26/20 15:33   NaN
# 2                 NaN      NaN   2/26/20 15:33   NaN
# 3                 NaN     True   2/27/20 09:26   NaN
# 4                 NaN      NaN   2/28/20 18:00   NaN
# ..                ...      ...             ...   ...
# 326               NaN     True  12/19/19 09:31   NaN
# 327               NaN      NaN  12/23/19 13:11   NaN
# 328               NaN      NaN  12/23/19 13:11   NaN
# 329               NaN      NaN  12/23/19 14:41   NaN
# 330               NaN      NaN  12/18/19 08:48   NaN
#
#                                                    url     source   yes    no  \
# 0    http://www.rasmussenreports.com/public_content...        538  47.0  52.0
# 1    https://morningconsult.com/wp-content/uploads/...        538  42.0  53.0
# 2    https://morningconsult.com/wp-content/uploads/...        538  43.0  55.0
# 3    http://www.rasmussenreports.com/public_content...        538  52.0  47.0
# 4    https://www.scribd.com/document/449414637/Fox-...        538  47.0  52.0
# ..                                                 ...        ...   ...   ...
# 326  http://www.rasmussenreports.com/public_content...  Rasmussen  49.0  49.0
# 327  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  42.0  51.0
# 328  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  44.0  54.0
# 329  https://mclaughlinonline.com/pols/wp-content/u...        538  46.0  53.0
# 330  https://www.ipsos.com/sites/default/files/ct/n...        538  41.0  53.0
#
#      count
# 0      330
# 1      329
# 2      328
# 3      327
# 4      326
# ..     ...
# 326      4
# 327      3
# 328      2
# 329      1
# 330      0
#
# [331 rows x 28 columns]

# %%
acq_df.plot(kind='line', x='count', y='yes')

# %%
acq_df_train = acq_df.loc[248:].copy()
acq_df_test = acq_df.loc[:249].copy()

acq_X_train = acq_df_train[["count"]]
acq_X_test = acq_df_test[["count"]]
acq_y_train = acq_df_train["yes"]

acq_model = LinearRegression()
acq_model.fit(X=acq_X_train, y=acq_y_train)
acq_model.predict(X=acq_X_test)

acq_X_new = pd.DataFrame()
# create a sequence of 200 evenly spaced numbers from 0 to 50
acq_X_new["count"] = np.linspace(0, 83, num=5)

# create a Series out of the predicted values
# (trailing underscore indicates fitted values)
acq_y_new_ = pd.Series(
    acq_model.predict(acq_X_new), # y values in Series.plot.line()
    index=acq_X_new["count"]    # x values in Series.plot.line()
)

# plot the data, then the model
acq_df_train.plot.line(x="count", y="yes")
acq_y_new_.plot.line(color='orange')
