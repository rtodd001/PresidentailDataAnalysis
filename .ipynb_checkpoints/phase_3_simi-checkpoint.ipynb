# %% [markdown]
# ## Did the impeachment skew the polls significantly?
# ## Was it predicatable?

# %% [markdown]
# Let's review the timeline of everything before we start
#
# - September-November : Inquiry
# - December 18, 2020 : Impeached by US HoR
# - January 16, 2020 : Passed the Senate
# - February 5, 2020 : Acquitted

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Create a training and testing model

# %% [markdown]
# What was Donald Trump's approval rating during his impeachment trial?

# %% [markdown]
# Impeached by the US HoR:

# %%
approval_df = pd.read_csv("president_approval_polls.csv")
approval_df.head()
# Out:
#    question_id  poll_id   cycle  state    politician  pollster_id  \
# 0       119194    64608  2020.0    NaN  Donald Trump          399
# 1       119031    64571  2020.0    NaN  Donald Trump         1189
# 2       119032    64571  2020.0    NaN  Donald Trump         1189
# 3       119075    64583  2020.0    NaN  Donald Trump          399
# 4       119267    64591  2020.0    NaN  Donald Trump          590
#
#                                        pollster sponsor_ids sponsors  \
# 0      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 1                               Morning Consult         NaN      NaN
# 2                               Morning Consult         NaN      NaN
# 3      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 4  Fox News/Beacon Research/Shaw & Co. Research         NaN      NaN
#
#                                display_name  ...  start_date end_date  \
# 0  Rasmussen Reports/Pulse Opinion Research  ...     2/25/20  2/27/20
# 1                           Morning Consult  ...     2/24/20  2/26/20
# 2                           Morning Consult  ...     2/24/20  2/26/20
# 3  Rasmussen Reports/Pulse Opinion Research  ...     2/24/20  2/26/20
# 4                                  Fox News  ...     2/23/20  2/26/20
#
#   sponsor_candidate  tracking     created_at notes  \
# 0               NaN      True  2/28/20 09:27   NaN
# 1               NaN       NaN  2/26/20 15:33   NaN
# 2               NaN       NaN  2/26/20 15:33   NaN
# 3               NaN      True  2/27/20 09:26   NaN
# 4               NaN       NaN  2/28/20 18:00   NaN
#
#                                                  url source   yes    no
# 0  http://www.rasmussenreports.com/public_content...    538  47.0  52.0
# 1  https://morningconsult.com/wp-content/uploads/...    538  42.0  53.0
# 2  https://morningconsult.com/wp-content/uploads/...    538  43.0  55.0
# 3  http://www.rasmussenreports.com/public_content...    538  52.0  47.0
# 4  https://www.scribd.com/document/449414637/Fox-...    538  47.0  52.0
#
# [5 rows x 27 columns]

# %%
approval_df.dtypes
# Out:
# question_id               int64
# poll_id                   int64
# cycle                   float64
# state                   float64
# politician               object
# pollster_id               int64
# pollster                 object
# sponsor_ids              object
# sponsors                 object
# display_name             object
# pollster_rating_id      float64
# pollster_rating_name     object
# fte_grade                object
# sample_size               int64
# population               object
# population_full          object
# methodology              object
# start_date               object
# end_date                 object
# sponsor_candidate       float64
# tracking                 object
# created_at               object
# notes                    object
# url                      object
# source                   object
# yes                     float64
# no                      float64
# dtype: object

# %%
house = approval_df.loc[:330].copy()
house.tail()
# Out:
#      question_id  poll_id   cycle  state    politician  pollster_id  \
# 326       115079    63154  2019.0    NaN  Donald Trump          399
# 327       115132    63177  2020.0    NaN  Donald Trump          568
# 328       115133    63177  2020.0    NaN  Donald Trump          568
# 329       115143    63183  2020.0    NaN  Donald Trump          294
# 330       114969    63145  2020.0    NaN  Donald Trump          744
#
#                                      pollster sponsor_ids sponsors  \
# 326  Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 327                                    YouGov         NaN      NaN
# 328                                    YouGov         NaN      NaN
# 329                   McLaughlin & Associates         NaN      NaN
# 330                                     Ipsos          71  Reuters
#
#                                  display_name  ...  start_date  end_date  \
# 326  Rasmussen Reports/Pulse Opinion Research  ...    12/16/19  12/18/19
# 327                                    YouGov  ...    12/16/19  12/18/19
# 328                                    YouGov  ...    12/16/19  12/18/19
# 329                   McLaughlin & Associates  ...    12/14/19  12/18/19
# 330                                     Ipsos  ...    12/16/19  12/17/19
#
#     sponsor_candidate  tracking      created_at notes  \
# 326               NaN      True  12/19/19 09:31   NaN
# 327               NaN       NaN  12/23/19 13:11   NaN
# 328               NaN       NaN  12/23/19 13:11   NaN
# 329               NaN       NaN  12/23/19 14:41   NaN
# 330               NaN       NaN  12/18/19 08:48   NaN
#
#                                                    url     source   yes    no
# 326  http://www.rasmussenreports.com/public_content...  Rasmussen  49.0  49.0
# 327  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  42.0  51.0
# 328  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  44.0  54.0
# 329  https://mclaughlinonline.com/pols/wp-content/u...        538  46.0  53.0
# 330  https://www.ipsos.com/sites/default/files/ct/n...        538  41.0  53.0
#
# [5 rows x 27 columns]

# %%
house_df = house.set_index('poll_id')
A = np.arange(len(house_df))
A = np.flip(A,0)
house_df['count'] = A
house_df.reset_index(inplace = True)
house_df.head()
# Out:
#    poll_id  question_id   cycle  state    politician  pollster_id  \
# 0    64608       119194  2020.0    NaN  Donald Trump          399
# 1    64571       119031  2020.0    NaN  Donald Trump         1189
# 2    64571       119032  2020.0    NaN  Donald Trump         1189
# 3    64583       119075  2020.0    NaN  Donald Trump          399
# 4    64591       119267  2020.0    NaN  Donald Trump          590
#
#                                        pollster sponsor_ids sponsors  \
# 0      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 1                               Morning Consult         NaN      NaN
# 2                               Morning Consult         NaN      NaN
# 3      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 4  Fox News/Beacon Research/Shaw & Co. Research         NaN      NaN
#
#                                display_name  ...  end_date sponsor_candidate  \
# 0  Rasmussen Reports/Pulse Opinion Research  ...   2/27/20               NaN
# 1                           Morning Consult  ...   2/26/20               NaN
# 2                           Morning Consult  ...   2/26/20               NaN
# 3  Rasmussen Reports/Pulse Opinion Research  ...   2/26/20               NaN
# 4                                  Fox News  ...   2/26/20               NaN
#
#   tracking     created_at notes  \
# 0     True  2/28/20 09:27   NaN
# 1      NaN  2/26/20 15:33   NaN
# 2      NaN  2/26/20 15:33   NaN
# 3     True  2/27/20 09:26   NaN
# 4      NaN  2/28/20 18:00   NaN
#
#                                                  url source   yes    no  count
# 0  http://www.rasmussenreports.com/public_content...    538  47.0  52.0    330
# 1  https://morningconsult.com/wp-content/uploads/...    538  42.0  53.0    329
# 2  https://morningconsult.com/wp-content/uploads/...    538  43.0  55.0    328
# 3  http://www.rasmussenreports.com/public_content...    538  52.0  47.0    327
# 4  https://www.scribd.com/document/449414637/Fox-...    538  47.0  52.0    326
#
# [5 rows x 28 columns]

# %%
house_df.plot(kind='line', x='count', y='yes')

# %%
house_df_train = house_df.loc[247:].copy()
house_df_test = house_df.loc[:248].copy()

X_train = house_df_train[["count"]]
X_test = house_df_test[["count"]]
y_train = house_df_train["yes"]

model = LinearRegression()
model.fit(X=X_train, y=y_train)
model.predict(X=X_test)

X_new = pd.DataFrame()
# create a sequence of 200 evenly spaced numbers from 0 to 50
X_new["count"] = np.linspace(0, 83, num=25)

# create a Series out of the predicted values
# (trailing underscore indicates fitted values)
y_new_ = pd.Series(
    model.predict(X_new), # y values in Series.plot.line()
    index=X_new["count"]    # x values in Series.plot.line()
)

# plot the data, then the model
house_df_train.plot.line(x="count", y="yes")
y_new_.plot.line()

# %% [markdown]
# Passed the Senate: Jan 16 2020

# %%
senate = approval_df.loc[211:].copy()
senate.head()
# Out:
#      question_id  poll_id   cycle  state    politician  pollster_id  \
# 211       115871    63293  2020.0    NaN  Donald Trump          568
# 212       115872    63293  2020.0    NaN  Donald Trump          568
# 213       115815    63284  2020.0    NaN  Donald Trump          568
# 214       115816    63284  2020.0    NaN  Donald Trump          568
# 215       115829    63287  2020.0    NaN  Donald Trump          399
#
#                                      pollster sponsor_ids sponsors  \
# 211                                    YouGov         NaN      NaN
# 212                                    YouGov         NaN      NaN
# 213                                    YouGov         NaN      NaN
# 214                                    YouGov         NaN      NaN
# 215  Rasmussen Reports/Pulse Opinion Research         NaN      NaN
#
#                                  display_name  ...  start_date end_date  \
# 211                                    YouGov  ...     1/14/20  1/16/20
# 212                                    YouGov  ...     1/14/20  1/16/20
# 213                                    YouGov  ...     1/13/20  1/15/20
# 214                                    YouGov  ...     1/13/20  1/15/20
# 215  Rasmussen Reports/Pulse Opinion Research  ...     1/13/20  1/15/20
#
#     sponsor_candidate  tracking     created_at notes  \
# 211               NaN       NaN  1/17/20 11:08   NaN
# 212               NaN       NaN  1/17/20 11:08   NaN
# 213               NaN       NaN  1/15/20 14:53   NaN
# 214               NaN       NaN  1/15/20 14:53   NaN
# 215               NaN      True  1/16/20 09:31   NaN
#
#                                                    url     source   yes    no
# 211  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  40.0  52.0
# 212  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  42.0  56.0
# 213  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  39.0  52.0
# 214  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  43.0  54.0
# 215  http://www.rasmussenreports.com/public_content...  Rasmussen  51.0  47.0
#
# [5 rows x 27 columns]

# %%
senate_df = senate.set_index('poll_id')
B = np.arange(len(senate_df))
B = np.flip(B,0)
senate_df['count'] = B
senate_df.reset_index(inplace = True)
senate_df
# Out:
#       poll_id  question_id   cycle  state    politician  pollster_id  \
# 0       63293       115871  2020.0    NaN  Donald Trump          568
# 1       63293       115872  2020.0    NaN  Donald Trump          568
# 2       63284       115815  2020.0    NaN  Donald Trump          568
# 3       63284       115816  2020.0    NaN  Donald Trump          568
# 4       63287       115829  2020.0    NaN  Donald Trump          399
# ...       ...          ...     ...    ...           ...          ...
# 6628    49426        77560  2017.0    NaN  Donald Trump          744
# 6629    49426        77599  2017.0    NaN  Donald Trump          744
# 6630    49262        77274  2017.0    NaN  Donald Trump          169
# 6631    49249        77261  2017.0    NaN  Donald Trump         1189
# 6632    49253        77265  2017.0    NaN  Donald Trump          169
#
#                                       pollster sponsor_ids  sponsors  \
# 0                                       YouGov         NaN       NaN
# 1                                       YouGov         NaN       NaN
# 2                                       YouGov         NaN       NaN
# 3                                       YouGov         NaN       NaN
# 4     Rasmussen Reports/Pulse Opinion Research         NaN       NaN
# ...                                        ...         ...       ...
# 6628                                     Ipsos          71   Reuters
# 6629                                     Ipsos          71   Reuters
# 6630                                    Gallup         NaN       NaN
# 6631                           Morning Consult         538  Politico
# 6632                                    Gallup         NaN       NaN
#
#                                   display_name  ...  end_date  \
# 0                                       YouGov  ...   1/16/20
# 1                                       YouGov  ...   1/16/20
# 2                                       YouGov  ...   1/15/20
# 3                                       YouGov  ...   1/15/20
# 4     Rasmussen Reports/Pulse Opinion Research  ...   1/15/20
# ...                                        ...  ...       ...
# 6628                                     Ipsos  ...   1/24/17
# 6629                                     Ipsos  ...   1/24/17
# 6630                                    Gallup  ...   1/23/17
# 6631                           Morning Consult  ...   1/22/17
# 6632                                    Gallup  ...   1/22/17
#
#      sponsor_candidate tracking     created_at notes  \
# 0                  NaN      NaN  1/17/20 11:08   NaN
# 1                  NaN      NaN  1/17/20 11:08   NaN
# 2                  NaN      NaN  1/15/20 14:53   NaN
# 3                  NaN      NaN  1/15/20 14:53   NaN
# 4                  NaN     True  1/16/20 09:31   NaN
# ...                ...      ...            ...   ...
# 6628               NaN     True   3/1/17 17:53   NaN
# 6629               NaN     True   3/1/17 17:53   NaN
# 6630               NaN     True   2/6/17 17:48   NaN
# 6631               NaN      NaN   2/6/17 17:42   NaN
# 6632               NaN     True   2/6/17 17:42   NaN
#
#                                                     url              source  \
# 0     https://d25d2506sfb94s.cloudfront.net/cumulus_...                 538
# 1     https://d25d2506sfb94s.cloudfront.net/cumulus_...                 538
# 2     https://d25d2506sfb94s.cloudfront.net/cumulus_...                 538
# 3     https://d25d2506sfb94s.cloudfront.net/cumulus_...                 538
# 4     http://www.rasmussenreports.com/public_content...           Rasmussen
# ...                                                 ...                 ...
# 6628  http://polling.reuters.com/#poll/CP3_2/filters...             Reuters
# 6629            http://polling.reuters.com/#poll/CP3_2/  Huffpost | Reuters
# 6630  http://www.gallup.com/poll/201617/gallup-daily...      538 | Huffpost
# 6631  http://static.politico.com/9b/13/82a3baf542ae9...      538 | Huffpost
# 6632  http://www.gallup.com/poll/201617/gallup-daily...      538 | Huffpost
#
#        yes    no  count
# 0     40.0  52.0   6632
# 1     42.0  56.0   6631
# 2     39.0  52.0   6630
# 3     43.0  54.0   6629
# 4     51.0  47.0   6628
# ...    ...   ...    ...
# 6628  45.2  44.3      4
# 6629  42.1  45.2      3
# 6630  45.0  46.0      2
# 6631  46.0  37.0      1
# 6632  45.0  45.0      0
#
# [6633 rows x 28 columns]

# %%
senate_df.plot(kind='scatter', x='count', y='yes')

# %%
senate_df_train = senate_df.loc[4974:].copy()
senate_df_test = senate_df.loc[:4975].copy()

senate_X_train = senate_df_train[["count"]]
senate_X_test = senate_df_test[["count"]]
senate_y_train = senate_df_train["yes"]

senate_model = LinearRegression()
senate_model.fit(X=senate_X_train, y=senate_y_train)
senate_model.predict(X=senate_X_test)

senate_X_new = pd.DataFrame()
# create a sequence of 200 evenly spaced numbers from 0 to 50
senate_X_new["count"] = np.linspace(0, 1700, num=200)

# create a Series out of the predicted values
# (trailing underscore indicates fitted values)
senate_y_new_ = pd.Series(
    senate_model.predict(senate_X_new), # y values in Series.plot.line()
    index=senate_X_new["count"]    # x values in Series.plot.line()
)

# plot the data, then the model
senate_df_train.plot.scatter(x="count", y="yes")
# plotting the line gets messed up for whatever reason
senate_y_new_.plot.line()
