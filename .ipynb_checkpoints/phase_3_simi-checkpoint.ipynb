# %% [markdown]
# ## Did the impeachment skew the polls significantly?
# ## Was it predicatable?

# %% [markdown]
# Let's review the timeline of everything before we start
#
# - September-November : Inquiry
# - December 18, 2020 : Impeached by US HoR
# - January 16, 2020 : Passed the Senate
# - February 5, 2020 : Acquitted

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Create a training and testing model

# %% [markdown]
# What was Donald Trump's approval rating during his impeachment trial?

# %%
approval_df = pd.read_csv("president_approval_polls.csv")
approval_df.head()
# Out:
#    question_id  poll_id   cycle  state    politician  pollster_id  \
# 0       119194    64608  2020.0    NaN  Donald Trump          399
# 1       119031    64571  2020.0    NaN  Donald Trump         1189
# 2       119032    64571  2020.0    NaN  Donald Trump         1189
# 3       119075    64583  2020.0    NaN  Donald Trump          399
# 4       119267    64591  2020.0    NaN  Donald Trump          590
#
#                                        pollster sponsor_ids sponsors  \
# 0      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 1                               Morning Consult         NaN      NaN
# 2                               Morning Consult         NaN      NaN
# 3      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 4  Fox News/Beacon Research/Shaw & Co. Research         NaN      NaN
#
#                                display_name  ...  start_date end_date  \
# 0  Rasmussen Reports/Pulse Opinion Research  ...     2/25/20  2/27/20
# 1                           Morning Consult  ...     2/24/20  2/26/20
# 2                           Morning Consult  ...     2/24/20  2/26/20
# 3  Rasmussen Reports/Pulse Opinion Research  ...     2/24/20  2/26/20
# 4                                  Fox News  ...     2/23/20  2/26/20
#
#   sponsor_candidate  tracking     created_at notes  \
# 0               NaN      True  2/28/20 09:27   NaN
# 1               NaN       NaN  2/26/20 15:33   NaN
# 2               NaN       NaN  2/26/20 15:33   NaN
# 3               NaN      True  2/27/20 09:26   NaN
# 4               NaN       NaN  2/28/20 18:00   NaN
#
#                                                  url source   yes    no
# 0  http://www.rasmussenreports.com/public_content...    538  47.0  52.0
# 1  https://morningconsult.com/wp-content/uploads/...    538  42.0  53.0
# 2  https://morningconsult.com/wp-content/uploads/...    538  43.0  55.0
# 3  http://www.rasmussenreports.com/public_content...    538  52.0  47.0
# 4  https://www.scribd.com/document/449414637/Fox-...    538  47.0  52.0
#
# [5 rows x 27 columns]

# %%
approval_df.dtypes
# Out:
# question_id               int64
# poll_id                   int64
# cycle                   float64
# state                   float64
# politician               object
# pollster_id               int64
# pollster                 object
# sponsor_ids              object
# sponsors                 object
# display_name             object
# pollster_rating_id      float64
# pollster_rating_name     object
# fte_grade                object
# sample_size               int64
# population               object
# population_full          object
# methodology              object
# start_date               object
# end_date                 object
# sponsor_candidate       float64
# tracking                 object
# created_at               object
# notes                    object
# url                      object
# source                   object
# yes                     float64
# no                      float64
# dtype: object

# %%
house = approval_df.loc[:330].copy()
house.tail()
# Out:
#      question_id  poll_id   cycle  state    politician  pollster_id  \
# 326       115079    63154  2019.0    NaN  Donald Trump          399
# 327       115132    63177  2020.0    NaN  Donald Trump          568
# 328       115133    63177  2020.0    NaN  Donald Trump          568
# 329       115143    63183  2020.0    NaN  Donald Trump          294
# 330       114969    63145  2020.0    NaN  Donald Trump          744
#
#                                      pollster sponsor_ids sponsors  \
# 326  Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 327                                    YouGov         NaN      NaN
# 328                                    YouGov         NaN      NaN
# 329                   McLaughlin & Associates         NaN      NaN
# 330                                     Ipsos          71  Reuters
#
#                                  display_name  ...  start_date  end_date  \
# 326  Rasmussen Reports/Pulse Opinion Research  ...    12/16/19  12/18/19
# 327                                    YouGov  ...    12/16/19  12/18/19
# 328                                    YouGov  ...    12/16/19  12/18/19
# 329                   McLaughlin & Associates  ...    12/14/19  12/18/19
# 330                                     Ipsos  ...    12/16/19  12/17/19
#
#     sponsor_candidate  tracking      created_at notes  \
# 326               NaN      True  12/19/19 09:31   NaN
# 327               NaN       NaN  12/23/19 13:11   NaN
# 328               NaN       NaN  12/23/19 13:11   NaN
# 329               NaN       NaN  12/23/19 14:41   NaN
# 330               NaN       NaN  12/18/19 08:48   NaN
#
#                                                    url     source   yes    no
# 326  http://www.rasmussenreports.com/public_content...  Rasmussen  49.0  49.0
# 327  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  42.0  51.0
# 328  https://d25d2506sfb94s.cloudfront.net/cumulus_...        538  44.0  54.0
# 329  https://mclaughlinonline.com/pols/wp-content/u...        538  46.0  53.0
# 330  https://www.ipsos.com/sites/default/files/ct/n...        538  41.0  53.0
#
# [5 rows x 27 columns]

# %%
house_df = house.set_index('poll_id')
A = np.arange(len(house_df))
A = np.flip(A,0)
house_df['count'] = A
house_df.reset_index(inplace = True)
house_df.head()
# Out:
#    poll_id  question_id   cycle  state    politician  pollster_id  \
# 0    64608       119194  2020.0    NaN  Donald Trump          399
# 1    64571       119031  2020.0    NaN  Donald Trump         1189
# 2    64571       119032  2020.0    NaN  Donald Trump         1189
# 3    64583       119075  2020.0    NaN  Donald Trump          399
# 4    64591       119267  2020.0    NaN  Donald Trump          590
#
#                                        pollster sponsor_ids sponsors  \
# 0      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 1                               Morning Consult         NaN      NaN
# 2                               Morning Consult         NaN      NaN
# 3      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 4  Fox News/Beacon Research/Shaw & Co. Research         NaN      NaN
#
#                                display_name  ...  end_date sponsor_candidate  \
# 0  Rasmussen Reports/Pulse Opinion Research  ...   2/27/20               NaN
# 1                           Morning Consult  ...   2/26/20               NaN
# 2                           Morning Consult  ...   2/26/20               NaN
# 3  Rasmussen Reports/Pulse Opinion Research  ...   2/26/20               NaN
# 4                                  Fox News  ...   2/26/20               NaN
#
#   tracking     created_at notes  \
# 0     True  2/28/20 09:27   NaN
# 1      NaN  2/26/20 15:33   NaN
# 2      NaN  2/26/20 15:33   NaN
# 3     True  2/27/20 09:26   NaN
# 4      NaN  2/28/20 18:00   NaN
#
#                                                  url source   yes    no  count
# 0  http://www.rasmussenreports.com/public_content...    538  47.0  52.0    330
# 1  https://morningconsult.com/wp-content/uploads/...    538  42.0  53.0    329
# 2  https://morningconsult.com/wp-content/uploads/...    538  43.0  55.0    328
# 3  http://www.rasmussenreports.com/public_content...    538  52.0  47.0    327
# 4  https://www.scribd.com/document/449414637/Fox-...    538  47.0  52.0    326
#
# [5 rows x 28 columns]

# %%
house_df.plot(kind='line', x='count', y='yes')

# %%
house_df_train = house_df.loc[247:].copy()
house_df_test = house_df.loc[:248].copy()

X_train = house_df_train[["count"]]
X_test = house_df_test[["count"]]
y_train = house_df_train["yes"]

model = LinearRegression()
model.fit(X=X_train, y=y_train)
model.predict(X=X_test)

X_new = pd.DataFrame()
# create a sequence of 200 evenly spaced numbers from 0 to 50
X_new["count"] = np.linspace(0, 83, num=25)

# create a Series out of the predicted values
# (trailing underscore indicates fitted values)
y_new_ = pd.Series(
    model.predict(X_new), # y values in Series.plot.line()
    index=X_new["count"]    # x values in Series.plot.line()
)

# plot the data, then the model
house_df_train.plot.line(x="count", y="yes")
y_new_.plot.line()
