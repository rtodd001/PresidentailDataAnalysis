# %% [markdown]
# # CS 105 Project Phase 2

# %% [markdown]
# Our objective is to assess how the impeachment trial of Donald Trump has affected support of Democratic candidates and the President as he heads towards re-election. We will look at polling data from before, during, and after the impeachment trials and plot trends according to different groupings such as region (social group), age, gender, economic group, and political orientation. After analyzing this data, we will make predictions for each group and who they want to be voted into office for the 2020 election in November.

# %% [markdown]
# Visual requirements:
#
# "You must include a histogram, at least two scatter plots or a pair-wise
# scatter plot, a parallel coordinates plot, and a box-plot. If a plot is not applicable in your case,
# then note that and include a different plot."

# %%
import pandas as pd
import matplotlib.pyplot as plt
def read(file_name):
    df_temp3 = pd.read_csv(file_name)
    list(df_temp3.iloc[1, :])
    arrays = [['All', 'All', 'Gender', 
                        'Gender', 'Age', 'Age', 
                        'Age', 'Age', '<50/50+',
                        '<50/50+', 'Race', 'Race',
                        'Race', 'Race', 'Race',
                        'Race', 'Class', 'Class',
                        'Class', 'Class', 'White X Class',
                        'White X Class', 'Paycheck', 'Paycheck',
                        'Paycheck', 'Paycheck', 'Paycheck',
                        'Party Affiliation', 'Party Affiliation', 'Party Affiliation',
                        'Ideology', 'Ideology', 'Ideology',
                        'Ideology', 'Ideology', '2016 Vote', '2016 Vote',
                        'Education', 'Education', 'Education',
                        'Income', 'Income', 'Income',
                        'Marital Status', 'Marital Status', 'Marital Status',
                        'Child < 18', 'Child < 18', 'Single Parent',
                        'Single Parent', 'Religion', 'Religion',
                        'Religion', 'Religion', 'Attend Religious Service',
                        'Attend Religious Service', 'Attend Religious Service', 'Evangelical',
                        'Evangelical', 'Aborition', 'Abortion',
                        'Abortion', 'Union HH', 'Union HH',
                        'Military HH', 'Military HH', 'LGBTQ HH',
                        'LGBTQ HH', 'Urbanicity', 'Urbanicity',
                        'Urbanicity', 'Suburban', 'Suburban',
                        'Region', 'Region', 'Region',
                        'Region'],list(df_temp3.iloc[0, :])]
    tuples = list(zip(*arrays))
    index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
    df_temp3 = pd.DataFrame(df_temp3.to_numpy(), columns=index)
    df_temp3 = df_temp3.drop(0)
    return df_temp3

# %% [markdown]
# ## FiveThirtyEight

# %% [markdown]
# National polling data of who is leading in the Democratic primary election, last updated February 29, 2020

# %%
primary_df = pd.read_csv("president_primary_polls.csv")
primary_df.head()
# Out:
# /usr/local/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (19,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    question_id  poll_id  cycle       state  pollster_id  \
# 0       119292    64627   2020  California         1539
# 1       119292    64627   2020  California         1539
# 2       119292    64627   2020  California         1539
# 3       119292    64627   2020  California         1539
# 4       119292    64627   2020  California         1539
#
#                 pollster sponsor_ids sponsors           display_name  \
# 0  Point Blank Political         NaN      NaN  Point Blank Political
# 1  Point Blank Political         NaN      NaN  Point Blank Political
# 2  Point Blank Political         NaN      NaN  Point Blank Political
# 3  Point Blank Political         NaN      NaN  Point Blank Political
# 4  Point Blank Political         NaN      NaN  Point Blank Political
#
#    pollster_rating_id  ... nationwide_batch     created_at  notes  \
# 0               550.0  ...            False  2/29/20 09:28    NaN
# 1               550.0  ...            False  2/29/20 09:28    NaN
# 2               550.0  ...            False  2/29/20 09:28    NaN
# 3               550.0  ...            False  2/29/20 09:28    NaN
# 4               550.0  ...            False  2/29/20 09:28    NaN
#
#                                                  url    stage party  \
# 0  https://www.pointblankpolitical.com/2020-ca-de...  primary   DEM
# 1  https://www.pointblankpolitical.com/2020-ca-de...  primary   DEM
# 2  https://www.pointblankpolitical.com/2020-ca-de...  primary   DEM
# 3  https://www.pointblankpolitical.com/2020-ca-de...  primary   DEM
# 4  https://www.pointblankpolitical.com/2020-ca-de...  primary   DEM
#
#       answer candidate_id       candidate_name   pct
# 0    Sanders        13257      Bernard Sanders  34.1
# 1     Warren        13258     Elizabeth Warren  14.0
# 2      Biden        13256  Joseph R. Biden Jr.  14.0
# 3  Bloomberg        13289    Michael Bloomberg  11.7
# 4  Buttigieg        13345       Pete Buttigieg   8.8
#
# [5 rows x 33 columns]

# %% [markdown]
# We only need the latest poll data so we need to get the data with the last poll_id:

# %%
primary_latest = primary_df.set_index("poll_id").loc[64627]
primary_latest
# Out:
#          question_id  cycle       state  pollster_id               pollster  \
# poll_id
# 64627         119292   2020  California         1539  Point Blank Political
# 64627         119292   2020  California         1539  Point Blank Political
# 64627         119292   2020  California         1539  Point Blank Political
# 64627         119292   2020  California         1539  Point Blank Political
# 64627         119292   2020  California         1539  Point Blank Political
# 64627         119292   2020  California         1539  Point Blank Political
# 64627         119292   2020  California         1539  Point Blank Political
# 64627         119292   2020  California         1539  Point Blank Political
# 64627         119293   2020  California         1539  Point Blank Political
# 64627         119293   2020  California         1539  Point Blank Political
# 64627         119294   2020  California         1539  Point Blank Political
# 64627         119294   2020  California         1539  Point Blank Political
# 64627         119295   2020  California         1539  Point Blank Political
# 64627         119295   2020  California         1539  Point Blank Political
#
#         sponsor_ids sponsors           display_name  pollster_rating_id  \
# poll_id
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
# 64627           NaN      NaN  Point Blank Political               550.0
#
#           pollster_rating_name  ... nationwide_batch     created_at  \
# poll_id                         ...
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
# 64627    Point Blank Political  ...            False  2/29/20 09:28
#
#                      notes                                                url  \
# poll_id
# 64627                  NaN  https://www.pointblankpolitical.com/2020-ca-de...
# 64627                  NaN  https://www.pointblankpolitical.com/2020-ca-de...
# 64627                  NaN  https://www.pointblankpolitical.com/2020-ca-de...
# 64627                  NaN  https://www.pointblankpolitical.com/2020-ca-de...
# 64627                  NaN  https://www.pointblankpolitical.com/2020-ca-de...
# 64627                  NaN  https://www.pointblankpolitical.com/2020-ca-de...
# 64627                  NaN  https://www.pointblankpolitical.com/2020-ca-de...
# 64627                  NaN  https://www.pointblankpolitical.com/2020-ca-de...
# 64627    head-to-head poll  https://www.pointblankpolitical.com/2020-ca-de...
# 64627    head-to-head poll  https://www.pointblankpolitical.com/2020-ca-de...
# 64627    head-to-head poll  https://www.pointblankpolitical.com/2020-ca-de...
# 64627    head-to-head poll  https://www.pointblankpolitical.com/2020-ca-de...
# 64627    head-to-head poll  https://www.pointblankpolitical.com/2020-ca-de...
# 64627    head-to-head poll  https://www.pointblankpolitical.com/2020-ca-de...
#
#            stage party     answer candidate_id       candidate_name   pct
# poll_id
# 64627    primary   DEM    Sanders        13257      Bernard Sanders  34.1
# 64627    primary   DEM     Warren        13258     Elizabeth Warren  14.0
# 64627    primary   DEM      Biden        13256  Joseph R. Biden Jr.  14.0
# 64627    primary   DEM  Bloomberg        13289    Michael Bloomberg  11.7
# 64627    primary   DEM  Buttigieg        13345       Pete Buttigieg   8.8
# 64627    primary   DEM  Klobuchar        13310        Amy Klobuchar   3.3
# 64627    primary   DEM     Steyer        13327           Tom Steyer   2.5
# 64627    primary   DEM    Gabbard        13343        Tulsi Gabbard   1.0
# 64627    primary   DEM    Sanders        13257      Bernard Sanders  49.6
# 64627    primary   DEM      Biden        13256  Joseph R. Biden Jr.  39.9
# 64627    primary   DEM    Sanders        13257      Bernard Sanders  57.2
# 64627    primary   DEM  Bloomberg        13289    Michael Bloomberg  32.2
# 64627    primary   DEM    Sanders        13257      Bernard Sanders  45.5
# 64627    primary   DEM     Warren        13258     Elizabeth Warren  35.6
#
# [14 rows x 32 columns]

# %%
d_primary_table = (primary_latest.groupby(["poll_id", "candidate_id", "candidate_name"]).pct.mean())
d_primary_table.to_frame()
# Out:
#                                             pct
# poll_id candidate_id candidate_name
# 64627   13256        Joseph R. Biden Jr.  26.95
#         13257        Bernard Sanders      46.60
#         13258        Elizabeth Warren     24.80
#         13289        Michael Bloomberg    21.95
#         13310        Amy Klobuchar         3.30
#         13327        Tom Steyer            2.50
#         13343        Tulsi Gabbard         1.00
#         13345        Pete Buttigieg        8.80

# %% [markdown]
# Visualizing with a scatter plot who is leading in the polls as of the latest data: (could only graph with the candidate_id for now)

# %%
d_primary_df = d_primary_table.reset_index()
d_primary_df.plot(kind='scatter', x='pct', y='candidate_id')
plt.show()

# %% [markdown]
# National polling data of who is leading in the general primary election, last updated February 29, 2020

# %%
general_df = pd.read_csv("president_polls.csv")
general_df.head()
# Out:
#    question_id  poll_id  cycle           state  pollster_id    pollster  \
# 0       119270    64622   2020  South Carolina         1528  AtlasIntel
# 1       119270    64622   2020  South Carolina         1528  AtlasIntel
# 2       119271    64622   2020  South Carolina         1528  AtlasIntel
# 3       119271    64622   2020  South Carolina         1528  AtlasIntel
# 4       119272    64622   2020  South Carolina         1528  AtlasIntel
#
#   sponsor_ids sponsors display_name  pollster_rating_id  ... nationwide_batch  \
# 0         NaN      NaN   AtlasIntel                 546  ...            False
# 1         NaN      NaN   AtlasIntel                 546  ...            False
# 2         NaN      NaN   AtlasIntel                 546  ...            False
# 3         NaN      NaN   AtlasIntel                 546  ...            False
# 4         NaN      NaN   AtlasIntel                 546  ...            False
#
#   ranked_choice_reallocated     created_at notes  \
# 0                     False  2/28/20 18:55   NaN
# 1                     False  2/28/20 18:55   NaN
# 2                     False  2/28/20 18:55   NaN
# 3                     False  2/28/20 18:55   NaN
# 4                     False  2/28/20 18:55   NaN
#
#                                                  url    stage   answer  \
# 0  https://projects.fivethirtyeight.com/polls/202...  general  Sanders
# 1  https://projects.fivethirtyeight.com/polls/202...  general    Trump
# 2  https://projects.fivethirtyeight.com/polls/202...  general   Warren
# 3  https://projects.fivethirtyeight.com/polls/202...  general    Trump
# 4  https://projects.fivethirtyeight.com/polls/202...  general    Biden
#
#         candidate_name  candidate_party   pct
# 0      Bernard Sanders              DEM  42.4
# 1         Donald Trump              REP  48.2
# 2     Elizabeth Warren              DEM  40.7
# 3         Donald Trump              REP  49.2
# 4  Joseph R. Biden Jr.              DEM  41.8
#
# [5 rows x 36 columns]

# %% [markdown]
# We only need the latest poll data so we need to get the data with the last poll_id:

# %%
general_latest = general_df.set_index("poll_id").loc[64622]
general_latest
# Out:
#          question_id  cycle           state  pollster_id    pollster  \
# poll_id
# 64622         119270   2020  South Carolina         1528  AtlasIntel
# 64622         119270   2020  South Carolina         1528  AtlasIntel
# 64622         119271   2020  South Carolina         1528  AtlasIntel
# 64622         119271   2020  South Carolina         1528  AtlasIntel
# 64622         119272   2020  South Carolina         1528  AtlasIntel
# 64622         119272   2020  South Carolina         1528  AtlasIntel
# 64622         119273   2020  South Carolina         1528  AtlasIntel
# 64622         119273   2020  South Carolina         1528  AtlasIntel
#
#         sponsor_ids sponsors display_name  pollster_rating_id  \
# poll_id
# 64622           NaN      NaN   AtlasIntel                 546
# 64622           NaN      NaN   AtlasIntel                 546
# 64622           NaN      NaN   AtlasIntel                 546
# 64622           NaN      NaN   AtlasIntel                 546
# 64622           NaN      NaN   AtlasIntel                 546
# 64622           NaN      NaN   AtlasIntel                 546
# 64622           NaN      NaN   AtlasIntel                 546
# 64622           NaN      NaN   AtlasIntel                 546
#
#         pollster_rating_name  ... nationwide_batch  ranked_choice_reallocated  \
# poll_id                       ...
# 64622             AtlasIntel  ...            False                      False
# 64622             AtlasIntel  ...            False                      False
# 64622             AtlasIntel  ...            False                      False
# 64622             AtlasIntel  ...            False                      False
# 64622             AtlasIntel  ...            False                      False
# 64622             AtlasIntel  ...            False                      False
# 64622             AtlasIntel  ...            False                      False
# 64622             AtlasIntel  ...            False                      False
#
#             created_at notes  \
# poll_id
# 64622    2/28/20 18:55   NaN
# 64622    2/28/20 18:55   NaN
# 64622    2/28/20 18:55   NaN
# 64622    2/28/20 18:55   NaN
# 64622    2/28/20 18:55   NaN
# 64622    2/28/20 18:55   NaN
# 64622    2/28/20 18:55   NaN
# 64622    2/28/20 18:55   NaN
#
#                                                        url    stage  \
# poll_id
# 64622    https://projects.fivethirtyeight.com/polls/202...  general
# 64622    https://projects.fivethirtyeight.com/polls/202...  general
# 64622    https://projects.fivethirtyeight.com/polls/202...  general
# 64622    https://projects.fivethirtyeight.com/polls/202...  general
# 64622    https://projects.fivethirtyeight.com/polls/202...  general
# 64622    https://projects.fivethirtyeight.com/polls/202...  general
# 64622    https://projects.fivethirtyeight.com/polls/202...  general
# 64622    https://projects.fivethirtyeight.com/polls/202...  general
#
#             answer       candidate_name candidate_party   pct
# poll_id
# 64622      Sanders      Bernard Sanders             DEM  42.4
# 64622        Trump         Donald Trump             REP  48.2
# 64622       Warren     Elizabeth Warren             DEM  40.7
# 64622        Trump         Donald Trump             REP  49.2
# 64622        Biden  Joseph R. Biden Jr.             DEM  41.8
# 64622        Trump         Donald Trump             REP  47.6
# 64622    Buttigieg       Pete Buttigieg             DEM  37.0
# 64622        Trump         Donald Trump             REP  47.9
#
# [8 rows x 35 columns]

# %%
general_election = (general_latest.groupby(["candidate_name"]).pct.mean())
general_election.to_frame()
# Out:
#                         pct
# candidate_name
# Bernard Sanders      42.400
# Donald Trump         48.225
# Elizabeth Warren     40.700
# Joseph R. Biden Jr.  41.800
# Pete Buttigieg       37.000

# %% [markdown]
# Visualizing the latest data with a bar graph. For this dataset, a bar graph is more appropriate than a scatterplot graph or box plot.

# %%
general_election.plot.bar(x="candidate_name", y="pct")

# %% [markdown]
# National polling data of presidental approval/disapproval rate, last updated February 27, 2020

# %%
approval_df = pd.read_csv("president_approval_polls.csv")
approval_df.head()
# Out:
#    question_id  poll_id   cycle  state    politician  pollster_id  \
# 0       119194    64608  2020.0    NaN  Donald Trump          399
# 1       119031    64571  2020.0    NaN  Donald Trump         1189
# 2       119032    64571  2020.0    NaN  Donald Trump         1189
# 3       119075    64583  2020.0    NaN  Donald Trump          399
# 4       119267    64591  2020.0    NaN  Donald Trump          590
#
#                                        pollster sponsor_ids sponsors  \
# 0      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 1                               Morning Consult         NaN      NaN
# 2                               Morning Consult         NaN      NaN
# 3      Rasmussen Reports/Pulse Opinion Research         NaN      NaN
# 4  Fox News/Beacon Research/Shaw & Co. Research         NaN      NaN
#
#                                display_name  ...  start_date end_date  \
# 0  Rasmussen Reports/Pulse Opinion Research  ...     2/25/20  2/27/20
# 1                           Morning Consult  ...     2/24/20  2/26/20
# 2                           Morning Consult  ...     2/24/20  2/26/20
# 3  Rasmussen Reports/Pulse Opinion Research  ...     2/24/20  2/26/20
# 4                                  Fox News  ...     2/23/20  2/26/20
#
#   sponsor_candidate  tracking     created_at notes  \
# 0               NaN      True  2/28/20 09:27   NaN
# 1               NaN       NaN  2/26/20 15:33   NaN
# 2               NaN       NaN  2/26/20 15:33   NaN
# 3               NaN      True  2/27/20 09:26   NaN
# 4               NaN       NaN  2/28/20 18:00   NaN
#
#                                                  url source   yes    no
# 0  http://www.rasmussenreports.com/public_content...    538  47.0  52.0
# 1  https://morningconsult.com/wp-content/uploads/...    538  42.0  53.0
# 2  https://morningconsult.com/wp-content/uploads/...    538  43.0  55.0
# 3  http://www.rasmussenreports.com/public_content...    538  52.0  47.0
# 4  https://www.scribd.com/document/449414637/Fox-...    538  47.0  52.0
#
# [5 rows x 27 columns]

# %% [markdown]
# Visualizing President Trump's current approval rating in a histogram:

# %%
approval_df.yes.plot.hist(legend=True)
approval_df.no.plot.hist(legend=True)

# %% [markdown]
# ## SurveyUSA

# %% [markdown]
# Data Below compares the distribution of candidate supporters comparing California to the rest of the US in January

# %%
survey1_df = read("surveyusa1/survey_data/survey_5.csv")
survey1_df
# Out:
# first                                               All       Gender         \
# second                          Credibility Interval:     All   Male Female
# 1                                           Joe Biden\t   168     92     76
# 2                                      Bernie Sanders\t   113     57     55
# 3                                    Elizabeth Warren\t   113     48     65
# 4                                      Pete Buttigieg\t    43     22     21
# 5                                        Mike Bloomberg    34     14     20
# 6                                         Andrew Yang\t    22     15      7
# 7                                            Tom Steyer    21      7     14
# 8                                         Tulsi Gabbard    14      8      6
# 9                                         Amy Klobuchar    10      3      7
# 10                                  Some Other Democrat     1      1      0
# 11                                            Undecided    25     10     16
# 12                                                Total   565    278    288
# 13      Composition of Likely Democratic Primary Voters  100%    49%    51%
#
# first    Age                  <50/50+       ... LGBTQ HH Urbanicity           \
# second 18-34 35-49 50-64  65+   18-49  50+  ...       No      Urban Suburban
# 1         20    33    56   59      53  115  ...      150         60       92
# 2         34    31    23   25      65   48  ...       99         53       53
# 3         22    42    27   21      65   48  ...       96         47       57
# 4          5    10    15   13      15   28  ...       24         13       27
# 5          4    11    15    5      15   19  ...       27         18       16
# 6         11     3     6    1      14    8  ...       20          9       13
# 7          6     4     3    8      10   11  ...       18         11        9
# 8          3     2     8    1       5    9  ...       13          4        5
# 9          1     2     6    1       3    7  ...        9          4        7
# 10         0     1     0    0       1    0  ...        1          0        1
# 11         1     2    12    9       4   22  ...       21          8       14
# 12       107   143   172  143     250  315  ...      479        227      294
# 13       19%   25%   30%  25%     44%  56%  ...      85%        40%      52%
#
# first        Suburban          Region
# second Rural     Male Female Central  Greater  Inland E Bay Area
# 1         17       41     51       32       76       39       21
# 2          7       24     29       15       61       16       22
# 3          8       19     39       20       43       28       21
# 4          3       15     12        5       20        7       10
# 5          0        4     12        6       12        9        7
# 6          0       10      4        1        8        7        7
# 7          1        4      5        2       10        3        6
# 8          5        3      2        3        6        1        4
# 9          0        2      5        2        1        2        5
# 10         0        1      0        1        0        0        0
# 11         3        5      9        9        9        4        3
# 12        44      127    167       96      247      116      106
# 13        8%      22%    30%      17%      44%      21%      19%
#
# [13 rows x 77 columns]

# %%
df_gender = survey1_df.loc[:, ['All', 'Gender']]
df_gender = df_gender.drop(('All','All'),axis=1)
df_gender = df_gender.drop([12,13])
df_gender = df_gender.astype({('Gender', 'Male'): 'int32'})
df_gender = df_gender.astype({('Gender', 'Female'): 'int32'})
df_gender.dtypes
df_gender = df_gender.set_index('All')

# %%
survey3_df = read("surveyusa3/survey_data/survey_4.csv")
survey3_df
# Out:
# first                                               All       Gender         \
# second                          Credibility Interval:     All   Male Female
# 1                                           Joe Biden\t   353    146    207
# 2                                      Bernie Sanders\t   225    111    114
# 3                                    Elizabeth Warren\t   156     53    102
# 4                                      Pete Buttigieg\t   103     58     45
# 5                                        Mike Bloomberg    93     43     50
# 6                                         Andrew Yang\t    43     24     19
# 7                                            Tom Steyer    33     11     22
# 8                                         Amy Klobuchar    27     12     15
# 9                                         Tulsi Gabbard    17     10      7
# 10                                  Some Other Democrat     7      3      3
# 11                                            Undecided    29      8     21
# 12                                                Total  1086    480    606
# 13      Composition of Likely Democratic Primary Voters  100%    44%    56%
#
# first    Age                  <50/50+       ... LGBTQ HH Urbanicity           \
# second 18-34 35-49 50-64  65+   18-49  50+  ...       No      Urban Suburban
# 1         51    76   123  103     127  226  ...      316        115      180
# 2         99    70    34   22     169   56  ...      184         82      104
# 3         41    45    34   35      86   70  ...      120         49       85
# 4         14    26    29   34      40   63  ...       77         29       53
# 5         18    25    17   34      42   51  ...       86         33       49
# 6         19    16     3    5      36    7  ...       39         25       15
# 7          3    10    13    7      13   20  ...       30         10       20
# 8          3     3     4   17       6   21  ...       26          5       12
# 9          4     2     8    2       7   11  ...       17          2       11
# 10         1     2     1    3       3    4  ...        7          1        5
# 11         5     3     9   13       8   21  ...       25          5       16
# 12       258   278   274  275     536  550  ...      928        357      552
# 13       24%   26%   25%  25%     49%  51%  ...      85%        33%      51%
#
# first        Suburban          Region
# second Rural     Male Female Northeas Midwest South West
# 1         57       70    111       65      70   160   57
# 2         39       57     47       37      52    73   63
# 3         22       25     60       29      28    59   40
# 4         21       28     25       16      35    28   25
# 5         12       24     25       30      10    33   21
# 6          3        9      6        9       8    14   11
# 7          3        5     15        6       2    11   14
# 8         10        8      4        9       3     8    7
# 9          4        7      4        3       4     3    7
# 10         0        2      3        3       0     2    1
# 11         8        4     12       12       8     8    2
# 12       177      238    314      219     221   400  247
# 13       16%      22%    29%      20%     20%   37%  23%
#
# [13 rows x 77 columns]

# %%
df_gender3 = survey3_df.loc[:, ['All', 'Gender']]
df_gender3 = df_gender3.drop(('All','All'),axis=1)
df_gender3 = df_gender3.drop([12,13])
df_gender3 = df_gender3.astype({('Gender', 'Male'): 'int32'})
df_gender3 = df_gender3.astype({('Gender', 'Female'): 'int32'})
df_gender3.dtypes
df_gender3 = df_gender3.set_index('All')

# %%
df_gender.plot.bar()
# Out:
# /usr/local/lib64/python3.6/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib64/python3.6/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# Candidate Support in California

# %%
df_gender3.plot.bar()

# %% [markdown]
# Candidate Support across the US
